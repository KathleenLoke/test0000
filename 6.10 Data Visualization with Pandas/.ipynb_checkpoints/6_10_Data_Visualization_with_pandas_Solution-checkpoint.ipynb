# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 5.1 Line Plot

# A. Make a dataframe called foot using the "international_football_results.csv" file
#    Perform a few exploratory data analysis operations before working with the data set
foot = pd.read_csv("international_football_results.csv")
# We'll use the .to_datetime method and .dt.year property to set the "year" column from a string to an integer
foot['year'] = pd.to_datetime(foot['date']).dt.year # "dt.year" extracts out the year and store in a nre column called 'year'

# %%
# B. Let's chart how many games occured in each year:

# First of all, let's look at the data we're going to plot
foot['year'].value_counts() # count the freuqucny of each unti value
# Out:
# year
# 2008    1087
# 2011    1077
# 2004    1059
# 2000    1022
# 2001    1014
#         ...
# 1878       2
# 1874       1
# 1873       1
# 1875       1
# 1872       1
# Name: count, Length: 147, dtype: int64

# %%
# The years are out of order! Fortunately, we can sort our column by its index with sort_index()
foot['year'].value_counts().sort_index() # sort it based on the index / default is ascending -if descending, plut "ascending = False"
# Out:
# year
# 1872       1
# 1873       1
# 1874       1
# 1875       1
# 1876       2
#         ...
# 2014     857
# 2015    1001
# 2016     918
# 2017     908
# 2018     390
# Name: count, Length: 147, dtype: int64

# %%
# Finally, we're ready to plot the change over time with .plot()
foot['year'].value_counts().sort_index().plot() # plot the line chart (by default), if categorical = might get error, won't automatically change
# Out:
# <Axes: xlabel='year'>

# %%
# 5.2 Bar Charts
# A. Let's see how many games each country played, represented as a bar chart
foot['country'].value_counts().head().plot(kind="bar", rot=0) 
# "value_counts()" counts the values and automatically sorts in descending order - it's part of the function of the code. 
# kind="bar" is for making it into a bar chart (and barh) for horizontal bar, "rot=" if the rotation of the text.
# Out:
# <Axes: xlabel='country'>

# %%
# B. Now let's plot the occurence of specific scores for the home team
foot['home_score'].value_counts().head().plot(kind="bar")
# Out:
# <Axes: xlabel='home_score'>

# %%
# C. Instead of sorting from highest to lowest value, let's sort the x axis in ascending order
foot['home_score'].value_counts().sort_index().head().plot(kind="bar")
# Out:
# <Axes: xlabel='home_score'>

# %%
# BONUS: Compare the home_score and away_score value counts to analyze home field advantage
# You will need to use the .apply method to use value_counts on each column of a dataframe
foot[['type', 'away_score']].apply(pd.Series.value_counts).head().plot(kind="bar") 
# 'foot[['home_score', 'away_score']]' - is the filter /// 'pd.Series.value_counts)' is counting the unique values, 'plot(kind="bar")' is polt a bar chart 
# 'foot[['home_score', 'away_score']] - multiple values, then need to list the values (if only 1 values, then it's juts 'value_count')
# Out:
# <Axes: >

# %%
# 5.3 Histograms
# A. Let's start with a new dataset. Create a dataframe called choc from the 'chocolate_ratings.csv' file
#    Inspect the data using some exploratory data analysis methods
choc = pd.read_csv('chocolate_ratings.csv')
choc.columns
pd.DataFrame(choc.dtypes, columns=["DataType"])
# Out:
#                                   DataType
# Company \n(Maker-if known)          object
# Specific Bean Origin\nor Bar Name   object
# REF                                  int64
# Review\nDate                         int64
# Cocoa\nPercent                      object
# Company\nLocation                   object
# Rating                             float64
# Bean\nType                          object
# Broad Bean\nOrigin                  object

# %%
choc.info
# Out:
# <bound method DataFrame.info of      Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                      A. Morin                       Agua Grande  1876
# 1                      A. Morin                             Kpime  1676
# 2                      A. Morin                            Atsane  1676
# 3                      A. Morin                             Akata  1680
# 4                      A. Morin                            Quilla  1704
# ...                         ...                               ...   ...
# 1790                     Zotter                              Peru   647
# 1791                     Zotter                             Congo   749
# 1792                     Zotter                      Kerala State   749
# 1793                     Zotter                      Kerala State   781
# 1794                     Zotter                Brazil, Mitzi Blue   486
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 0             2016            63%            France    3.75
# 1             2015            70%            France    2.75
# 2             2015            70%            France    3.00
# 3             2015            70%            France    3.50
# 4             2015            70%            France    3.50
# ...            ...            ...               ...     ...        ...
# 1790          2011            70%           Austria    3.75
# 1791          2011            65%           Austria    3.00  Forastero
# 1792          2011            65%           Austria    3.50  Forastero
# 1793          2011            62%           Austria    3.25
# 1794          2010            65%           Austria    3.00
#
#      Broad Bean\nOrigin
# 0              Sao Tome
# 1                  Togo
# 2                  Togo
# 3                  Togo
# 4                  Peru
# ...                 ...
# 1790               Peru
# 1791              Congo
# 1792              India
# 1793              India
# 1794             Brazil
#
# [1795 rows x 9 columns]>

# %%
# B. Now, let's explore the distribution of ratings
#    i. Start by plotting the Rating column in a histogram
choc['Rating'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
#    ii. Looking good! Let's see how granular we can get
#        Modify the number of bins to change how ranges are distributed
#choc['Rating'].plot(kind="hist", bins=3)
choc['Rating'].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#    iii. Now, let's add some descriptive labels to our chart using matplotlib
choc['Rating'].plot(kind='hist', bins=20)
plt.ylabel('Number of Ratings')
plt.xlabel('Chocolate Rating')
plt.title('Distribution of Chocolate Ratings');

# %%
# 5.4 Scatter Plots
# A. Is there a connection between Review Date and Rating? Plot them with a scatter plot
choc.plot(kind="scatter", x="Review\nDate", y="Rating" )
# Out:
# <Axes: xlabel='Review\nDate', ylabel='Rating'>

# %%
# B. Create a dataframe called avo from 'avocado.csv'.  Explore this new dataframe, then scatter plot correlation between Total Volume and AveragePrice
avo = pd.read_csv('avocado.csv')
avo.plot(kind='scatter', x='Total Volume', y='AveragePrice')

# To remove scientific notation like 1e7 from the x-labels
plt.ticklabel_format(useOffset=False, style='plain') # "plt.ticklabel_format(useOffset=False," is to remove that scientific notation, and just see actual values

# %% [markdown]
# ## Self-Practice

# %%
# 5.5 Visualizations to Hypotheses
# Create vbisualizations around any of the above datasets or our superstore datasets
# For at least one of the visualizations, attach a hypothesis or specific claim the chart supports

# %%
# 5.3 Histograms
# A. Let's start with a new dataset. Create a dataframe called choc from the 'chocolate_ratings.csv' file
#    Inspect the data using some exploratory data analysis methods
avo = pd.read_csv('avocado.csv')
avo.columns
pd.DataFrame(avo.dtypes, columns=["DataType"])
# Out:
#              DataType
# Unnamed: 0      int64
# Date           object
# AveragePrice  float64
# Total Volume  float64
# 4046          float64
# 4225          float64
# 4770          float64
# Total Bags    float64
# Small Bags    float64
# Large Bags    float64
# XLarge Bags   float64
# type           object
# year            int64
# region         object

# %%
avo.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]>

# %%
# B. Now, let's explore the distribution of price
#    i. Start by plotting the pricing column in a histogram
avo['AveragePrice'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
#    ii. Looking good! Let's see how granular we can get
#        Modify the number of bins to change how ranges are distributed
#avo['Rating'].plot(kind="hist", bins=3)
avo['AveragePrice'].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#    iii. Now, let's add some descriptive labels to our chart using matplotlib
avo['AveragePrice'].plot(kind='hist', bins=20)
plt.ylabel('Number of Sales')
plt.xlabel('Avocado Prices')
plt.title('Distribution of Avocado Prices');

# %%
# Add labels to each data point
for x, y in zip(avo_a.index, avo_a):
    ax.annotate(f'{y:.2f}', (x, y), textcoords="offset points", xytext=(0,5), ha='center')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 # Add labels to each data point
# ----> 2 for x, y in zip(avo_a.index, avo_a):
#       3     ax.annotate(f'{y:.2f}', (x, y), textcoords="offset points", xytext=(0,5), ha='center')
#
# NameError: name 'avo_a' is not defined

# %%
# 5.5 Sample Solution
# Uncomment to view the sample solution
'''
import matplotlib.pyplot as plt

# Set the index to 'year' for the DataFrame 'avo'
avo.set_index("year", inplace=True)

# Group by 'year' and calculate the mean of 'AveragePrice'
avo_a = avo.groupby("year")['AveragePrice'].mean()

# Plot the line chart
plt.figure(figsize=(10, 6))
ax = avo_a.plot(kind="line", marker='o', linestyle='-', color='b')

# Format x-axis labels to show whole numbers
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(integer=True))

# Add labels to each data point
for x, y in zip(avo_a.index, avo_a):
    ax.annotate(f'{y:.2f}', (x, y), textcoords="offset points", xytext=(0,5), ha='center')

plt.xlabel('Year')
plt.ylabel('Average Price')
plt.title('Average Price of Avocados Over Years')
plt.grid(True)
plt.show()
'''
# Out:
# '\nimport matplotlib.pyplot as plt\n\n# Set the index to \'year\' for the DataFrame \'avo\'\navo.set_index("year", inplace=True)\n\n# Group by \'year\' and calculate the mean of \'AveragePrice\'\navo_a = avo.groupby("year")[\'AveragePrice\'].mean()\n\n# Plot the line chart\nplt.figure(figsize=(10, 6))\nax = avo_a.plot(kind="line", marker=\'o\', linestyle=\'-\', color=\'b\')\n\n# Format x-axis labels to show whole numbers\nplt.gca().xaxis.set_major_locator(plt.MaxNLocator(integer=True))\n\n# Add labels to each data point\nfor x, y in zip(avo_a.index, avo_a):\n    ax.annotate(f\'{y:.2f}\', (x, y), textcoords="offset points", xytext=(0,5), ha=\'center\')\n\nplt.xlabel(\'Year\')\nplt.ylabel(\'Average Price\')\nplt.title(\'Average Price of Avocados Over Years\')\nplt.grid(True)\nplt.show()\n'
